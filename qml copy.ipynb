# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 2    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "quanvolution/" # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
import os
from PIL import Image
import numpy as np

# Path to the folder containing your dataset
dataset_path = "Data\AutismDataset\consolidated"

# List to store image paths and labels
image_paths = []
labels = []

# Define label indices for "autistic" and "non-autistic" classes
autistic_label = 0
non_autistic_label = 1

# Iterate through subfolders
for label, subfolder in enumerate(["Autistic", "Non_Autistic"]):
    subfolder_path = os.path.join(dataset_path, subfolder)
    
    # Iterate through images in the subfolder
    for filename in os.listdir(subfolder_path):
        if filename.endswith(".jpg"):
            image_path = os.path.join(subfolder_path, filename)
            image_paths.append(image_path)
            labels.append(label)

# Convert labels to numpy array
labels = np.array(labels)

# Function to load and preprocess images
def load_and_preprocess_images(image_paths):
    images = []
    for image_path in image_paths:
        img = Image.open(image_path)
        img = img.resize((desired_width, desired_height))  # Resize if needed
        img_array = np.array(img) / 255.0  # Normalize pixel values
        img_array = img_array[..., np.newaxis]  # Add extra dimension for convolution channels
        images.append(img_array)
    return np.array(images)

# Load and preprocess images
desired_width, desired_height = 28, 28  # Adjust the dimensions as needed
images = load_and_preprocess_images(image_paths)

# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
trainable_params = qml.numpy.random.uniform(0, np.pi, (n_layers, 4), requires_grad=True)

@qml.qnode(dev, interface="autograd")
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    for i in range(n_layers):
        for j in range(4):
            qml.RY(trainable_params[i, j], wires=j)  # Trainable rotation gates
        qml.broadcast(qml.CNOT, wires=[0, 1, 2, 3], pattern="ring")  

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
# Quantum pre-processing of train images
q_train_images = []
print("Quantum pre-processing of train images:")
for idx, img in enumerate(train_images):
    print("{}/{}        ".format(idx + 1, len(train_images)), end="\r")
    q_train_images.append(quanv(img))
q_train_images = np.asarray(q_train_images)

# Quantum pre-processing of test images
q_test_images = []
print("\nQuantum pre-processing of test images:")
for idx, img in enumerate(test_images):
    print("{}/{}        ".format(idx + 1, len(test_images)), end="\r")
    q_test_images.append(quanv(img))
q_test_images = np.asarray(q_test_images)

# Save pre-processed images
SAVE_PATH = "your_save_path/"
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
np.save(SAVE_PATH + "q_test_images.npy", q_test_images)
# Out:
# Quantum pre-processing of train images:
# 2352/2352
# Quantum pre-processing of test images:
# 588/588

# %%
import matplotlib.pyplot as plt

n_samples = 5
n_channels = 3  # Assuming RGB color images
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))

for k in range(n_samples):
    axes[0, k].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k].reshape(28, 28, 3))
    
    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, k].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c])

plt.tight_layout()
plt.show()

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 588/588 - 2s - loss: 0.6614 - accuracy: 0.6369 - val_loss: 0.5795 - val_accuracy: 0.6871 - 2s/epoch - 4ms/step
# Epoch 2/30
# 588/588 - 1s - loss: 0.5759 - accuracy: 0.7024 - val_loss: 0.6218 - val_accuracy: 0.6446 - 1s/epoch - 2ms/step
# Epoch 3/30
# 588/588 - 1s - loss: 0.5568 - accuracy: 0.7049 - val_loss: 0.5691 - val_accuracy: 0.7058 - 1s/epoch - 2ms/step
# Epoch 4/30
# 588/588 - 1s - loss: 0.5349 - accuracy: 0.7313 - val_loss: 0.5882 - val_accuracy: 0.6905 - 1s/epoch - 2ms/step
# Epoch 5/30
# 588/588 - 1s - loss: 0.5267 - accuracy: 0.7368 - val_loss: 0.5757 - val_accuracy: 0.7092 - 1s/epoch - 2ms/step
# Epoch 6/30
# 588/588 - 1s - loss: 0.5190 - accuracy: 0.7445 - val_loss: 0.6075 - val_accuracy: 0.6599 - 1s/epoch - 2ms/step
# Epoch 7/30
# 588/588 - 1s - loss: 0.5049 - accuracy: 0.7517 - val_loss: 0.5927 - val_accuracy: 0.6922 - 1s/epoch - 2ms/step
# Epoch 8/30
# 588/588 - 1s - loss: 0.5064 - accuracy: 0.7521 - val_loss: 0.5935 - val_accuracy: 0.6973 - 1s/epoch - 2ms/step
# Epoch 9/30
# 588/588 - 2s - loss: 0.4954 - accuracy: 0.7572 - val_loss: 0.6116 - val_accuracy: 0.6684 - 2s/epoch - 4ms/step
# Epoch 10/30
# 588/588 - 17s - loss: 0.4940 - accuracy: 0.7653 - val_loss: 0.6114 - val_accuracy: 0.6701 - 17s/epoch - 29ms/step
# Epoch 11/30
# 588/588 - 16s - loss: 0.4852 - accuracy: 0.7657 - val_loss: 0.6040 - val_accuracy: 0.6837 - 16s/epoch - 28ms/step
# Epoch 12/30
# 588/588 - 15s - loss: 0.4824 - accuracy: 0.7679 - val_loss: 0.6126 - val_accuracy: 0.6786 - 15s/epoch - 26ms/step
# Epoch 13/30
# 588/588 - 7s - loss: 0.4781 - accuracy: 0.7653 - val_loss: 0.6351 - val_accuracy: 0.6514 - 7s/epoch - 13ms/step
# Epoch 14/30
# 588/588 - 6s - loss: 0.4790 - accuracy: 0.7747 - val_loss: 0.6154 - val_accuracy: 0.6939 - 6s/epoch - 9ms/step
# Epoch 15/30
# 588/588 - 6s - loss: 0.4735 - accuracy: 0.7764 - val_loss: 0.6136 - val_accuracy: 0.6803 - 6s/epoch - 9ms/step
# Epoch 16/30
# 588/588 - 6s - loss: 0.4678 - accuracy: 0.7755 - val_loss: 0.6179 - val_accuracy: 0.6871 - 6s/epoch - 11ms/step
# Epoch 17/30
# 588/588 - 9s - loss: 0.4665 - accuracy: 0.7721 - val_loss: 0.6487 - val_accuracy: 0.6548 - 9s/epoch - 15ms/step
# Epoch 18/30
# 588/588 - 11s - loss: 0.4633 - accuracy: 0.7819 - val_loss: 0.6211 - val_accuracy: 0.6718 - 11s/epoch - 19ms/step
# Epoch 19/30
# 588/588 - 18s - loss: 0.4611 - accuracy: 0.7802 - val_loss: 0.6850 - val_accuracy: 0.6446 - 18s/epoch - 30ms/step
# Epoch 20/30
# 588/588 - 10s - loss: 0.4612 - accuracy: 0.7785 - val_loss: 0.6465 - val_accuracy: 0.6922 - 10s/epoch - 18ms/step
# Epoch 21/30
# 588/588 - 15s - loss: 0.4620 - accuracy: 0.7819 - val_loss: 0.6402 - val_accuracy: 0.6599 - 15s/epoch - 25ms/step
# Epoch 22/30
# 588/588 - 17s - loss: 0.4519 - accuracy: 0.7870 - val_loss: 0.6572 - val_accuracy: 0.6718 - 17s/epoch - 28ms/step
# Epoch 23/30
# 588/588 - 20s - loss: 0.4532 - accuracy: 0.7823 - val_loss: 0.6387 - val_accuracy: 0.6718 - 20s/epoch - 34ms/step
# Epoch 24/30
# 588/588 - 16s - loss: 0.4510 - accuracy: 0.7878 - val_loss: 0.6940 - val_accuracy: 0.6344 - 16s/epoch - 26ms/step
# Epoch 25/30
# 588/588 - 9s - loss: 0.4503 - accuracy: 0.7836 - val_loss: 0.7152 - val_accuracy: 0.6276 - 9s/epoch - 16ms/step
# Epoch 26/30
# 588/588 - 10s - loss: 0.4521 - accuracy: 0.7861 - val_loss: 0.6434 - val_accuracy: 0.6582 - 10s/epoch - 17ms/step
# Epoch 27/30
# 588/588 - 7s - loss: 0.4472 - accuracy: 0.7870 - val_loss: 0.6605 - val_accuracy: 0.6480 - 7s/epoch - 13ms/step
# Epoch 28/30
# 588/588 - 7s - loss: 0.4432 - accuracy: 0.7878 - val_loss: 0.6407 - val_accuracy: 0.6854 - 7s/epoch - 13ms/step
# Epoch 29/30
# 588/588 - 7s - loss: 0.4440 - accuracy: 0.7912 - val_loss: 0.6474 - val_accuracy: 0.6854 - 7s/epoch - 12ms/step
# Epoch 30/30
# 588/588 - 8s - loss: 0.4428 - accuracy: 0.7840 - val_loss: 0.6461 - val_accuracy: 0.6769 - 8s/epoch - 14ms/step

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 588/588 - 10s - loss: 0.7754 - accuracy: 0.5761 - val_loss: 1.0238 - val_accuracy: 0.5255 - 10s/epoch - 17ms/step
# Epoch 2/30
# 588/588 - 4s - loss: 0.7183 - accuracy: 0.6190 - val_loss: 1.0713 - val_accuracy: 0.5391 - 4s/epoch - 6ms/step
# Epoch 3/30
# 588/588 - 7s - loss: 0.7157 - accuracy: 0.6484 - val_loss: 0.7932 - val_accuracy: 0.5901 - 7s/epoch - 11ms/step
# Epoch 4/30
# 588/588 - 7s - loss: 0.6871 - accuracy: 0.6433 - val_loss: 0.6934 - val_accuracy: 0.6480 - 7s/epoch - 11ms/step
# Epoch 5/30
# 588/588 - 8s - loss: 0.6242 - accuracy: 0.6798 - val_loss: 0.5931 - val_accuracy: 0.7075 - 8s/epoch - 13ms/step
# Epoch 6/30
# 588/588 - 8s - loss: 0.6314 - accuracy: 0.6611 - val_loss: 0.7731 - val_accuracy: 0.6003 - 8s/epoch - 13ms/step
# Epoch 7/30
# 588/588 - 5s - loss: 0.6393 - accuracy: 0.6888 - val_loss: 0.5970 - val_accuracy: 0.7075 - 5s/epoch - 9ms/step
# Epoch 8/30
# 588/588 - 6s - loss: 0.6093 - accuracy: 0.6896 - val_loss: 0.6189 - val_accuracy: 0.6871 - 6s/epoch - 11ms/step
# Epoch 9/30
# 588/588 - 6s - loss: 0.6834 - accuracy: 0.6786 - val_loss: 0.6198 - val_accuracy: 0.6769 - 6s/epoch - 10ms/step
# Epoch 10/30
# 588/588 - 7s - loss: 0.6178 - accuracy: 0.6973 - val_loss: 0.6511 - val_accuracy: 0.6803 - 7s/epoch - 12ms/step
# Epoch 11/30
# 588/588 - 7s - loss: 0.6128 - accuracy: 0.6981 - val_loss: 0.9932 - val_accuracy: 0.5476 - 7s/epoch - 12ms/step
# Epoch 12/30
# 588/588 - 6s - loss: 0.6493 - accuracy: 0.6939 - val_loss: 0.7317 - val_accuracy: 0.6207 - 6s/epoch - 11ms/step
# Epoch 13/30
# 588/588 - 6s - loss: 0.6094 - accuracy: 0.7041 - val_loss: 0.6024 - val_accuracy: 0.7007 - 6s/epoch - 10ms/step
# Epoch 14/30
# 588/588 - 8s - loss: 0.6349 - accuracy: 0.7007 - val_loss: 0.6957 - val_accuracy: 0.6752 - 8s/epoch - 14ms/step
# Epoch 15/30
# 588/588 - 7s - loss: 0.5854 - accuracy: 0.7126 - val_loss: 0.7160 - val_accuracy: 0.6429 - 7s/epoch - 12ms/step
# Epoch 16/30
# 588/588 - 5s - loss: 0.5925 - accuracy: 0.7194 - val_loss: 0.6343 - val_accuracy: 0.6905 - 5s/epoch - 9ms/step
# Epoch 17/30
# 588/588 - 5s - loss: 0.5886 - accuracy: 0.7287 - val_loss: 0.6589 - val_accuracy: 0.6650 - 5s/epoch - 9ms/step
# Epoch 18/30
# 588/588 - 6s - loss: 0.5757 - accuracy: 0.7181 - val_loss: 0.9492 - val_accuracy: 0.5765 - 6s/epoch - 9ms/step
# Epoch 19/30
# 588/588 - 12s - loss: 0.5729 - accuracy: 0.7177 - val_loss: 0.6582 - val_accuracy: 0.6752 - 12s/epoch - 21ms/step
# Epoch 20/30
# 588/588 - 9s - loss: 0.5772 - accuracy: 0.7326 - val_loss: 0.6548 - val_accuracy: 0.6769 - 9s/epoch - 15ms/step
# Epoch 21/30
# 588/588 - 2s - loss: 0.6047 - accuracy: 0.7134 - val_loss: 0.8187 - val_accuracy: 0.6361 - 2s/epoch - 3ms/step
# Epoch 22/30
# 588/588 - 2s - loss: 0.5666 - accuracy: 0.7185 - val_loss: 0.6327 - val_accuracy: 0.6888 - 2s/epoch - 3ms/step
# Epoch 23/30
# 588/588 - 1s - loss: 0.5407 - accuracy: 0.7351 - val_loss: 1.0062 - val_accuracy: 0.5765 - 1s/epoch - 2ms/step
# Epoch 24/30
# 588/588 - 1s - loss: 0.5425 - accuracy: 0.7355 - val_loss: 0.7774 - val_accuracy: 0.6173 - 1s/epoch - 2ms/step
# Epoch 25/30
# 588/588 - 1s - loss: 0.5596 - accuracy: 0.7394 - val_loss: 0.6784 - val_accuracy: 0.6650 - 1s/epoch - 2ms/step
# Epoch 26/30
# 588/588 - 2s - loss: 0.5628 - accuracy: 0.7330 - val_loss: 0.6527 - val_accuracy: 0.6769 - 2s/epoch - 3ms/step
# Epoch 27/30
# 588/588 - 1s - loss: 0.5641 - accuracy: 0.7343 - val_loss: 0.6435 - val_accuracy: 0.6769 - 1s/epoch - 2ms/step
# Epoch 28/30
# 588/588 - 1s - loss: 0.5407 - accuracy: 0.7313 - val_loss: 0.8536 - val_accuracy: 0.6105 - 1s/epoch - 2ms/step
# Epoch 29/30
# 588/588 - 1s - loss: 0.5183 - accuracy: 0.7457 - val_loss: 0.6435 - val_accuracy: 0.6973 - 1s/epoch - 2ms/step
# Epoch 30/30
# 588/588 - 1s - loss: 0.5555 - accuracy: 0.7398 - val_loss: 1.0038 - val_accuracy: 0.5969 - 1s/epoch - 2ms/step

# %%
import matplotlib.pyplot as plt

plt.style.use("default")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
